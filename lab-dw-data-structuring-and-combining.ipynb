# %% [markdown]
# # Lab | Data Structuring and Combining Data

# %% [markdown]
# ## Challenge 1: Combining & Cleaning Data
#
# In this challenge, we will be working with the customer data from an insurance company, as we did in the two previous labs. The data can be found here:
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv
#
# But this time, we got new data, which can be found in the following 2 CSV files located at the links below.
#
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file2.csv
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file3.csv
#
# Note that you'll need to clean and format the new data.
#
# Observation:
# - One option is to first combine the three datasets and then apply the cleaning function to the new combined dataset
# - Another option would be to read the clean file you saved in the previous lab, and just clean the two new files and concatenate the three clean datasets

# %%
import pandas as pd

url1 = "https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv"
url2 = "https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file2.csv"
url3 = "https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file3.csv"

insurance_company_file1_df = pd.read_csv(url1)
insurance_company_file2_df = pd.read_csv(url2)
insurance_company_file3_df = pd.read_csv(url3)

display("DataFrame of Company 1:", insurance_company_file2_df)
print()
display("DataFrame of Company 2:", insurance_company_file2_df)
print()
display("DataFrame of Company 3:", insurance_company_file3_df)
# Out:
# 'DataFrame of Company 1:'
#     Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
# ...

# %%
# show me all infos about this DF
print("Info about DF original:")
print(insurance_company_file1_df.info())
print("Info about DF file2:")
print(insurance_company_file2_df.info())
print("Info about DF file3:")
print(insurance_company_file3_df.info())
# Out:
# Info about DF original:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4008 entries, 0 to 4007
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Customer                   1071 non-null   object
#  1   ST                         1071 non-null   object
#  2   GENDER                     954 non-null    object
#  3   Education                  1071 non-null   object
#  4   Customer Lifetime Value    1068 non-null   object
#  5   Income                     1071 non-null   float64
#  6   Monthly Premium Auto       1071 non-null   float64
#  7   Number of Open Complaints  1071 non-null   object
#  8   Policy Type                1071 non-null   object
#  9   Vehicle Class              1071 non-null   object
#  10  Total Claim Amount         1071 non-null   float64
# dtypes: float64(3), object(8)
# memory usage: 344.6+ KB
# None
# Info about DF file2:
# ...

# %%
print("Info about DF original:")
print(insurance_company_df.info())
# Out:
# Info about DF original:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4008 entries, 0 to 4007
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Customer                   1071 non-null   object
#  1   ST                         1071 non-null   object
#  2   GENDER                     954 non-null    object
#  3   Education                  1071 non-null   object
#  4   Customer Lifetime Value    1068 non-null   object
#  5   Income                     1071 non-null   float64
#  6   Monthly Premium Auto       1071 non-null   float64
#  7   Number of Open Complaints  1071 non-null   object
#  8   Policy Type                1071 non-null   object
#  9   Vehicle Class              1071 non-null   object
#  10  Total Claim Amount         1071 non-null   float64
# dtypes: float64(3), object(8)
# memory usage: 344.6+ KB
# None

# %%
# define function for data cleaning as we did in the previous lab (Cleaning Column Names, 
#Cleaning invalid Values, Formatting data types, Dealing with Null values)

def clean_data(df):
    
    #rename ST and column names in lower case, replace " " by "_"
    df.rename(columns={"ST": "state"}, inplace=True)
    df.columns = df.columns.str.lower().str.replace(" ", "_")
    
    # #Gender column contains various inconsistent values such as "F", "M", "Femal", "Male", "female", which need to be standardized, for example, to "M" and "F".
    df["gender"] = df["gender"].str.upper()
    df["gender"] = df["gender"].replace({"female": "F", "Male": "M", "Femal": "F", "Female": "F"})

    #State abbreviations be can replaced with its full name, for example "AZ": "Arizona", "Cali": "California", "WA": "Washington"
    state_dict = {"AZ": "Arizona", "Cali": "California", "WA": "Washington", "OR": "Oregon", "NE": "Nevada"}
    df['state'] = df['state'].replace(state_dict)
    
    #In education, "Bachelors" could be replaced by "Bachelor"
    df["education"] = df["education"].replace({"Bachelors": "Bachelor"})
    
    #In vehicle class, "Sports Car", "Luxury SUV" and "Luxury Car" could be replaced by "Luxury"
    luxury_car = {"sports car": "luxury", "luxury suv": "luxury", "luxury car": "luxury"}
    df["vehicle_class"] = df["vehicle_class"].replace(luxury_car)
    
    df['customer_lifetime_value'] = df['customer_lifetime_value'].astype(str)
    df['customer_lifetime_value'] = df['customer_lifetime_value'].replace('nan', pd.NA)
    df['customer_lifetime_value'] = df['customer_lifetime_value'].str.replace('%', '')

    
    
    
    return df

# %%
#cleaning the three files

insurance_company_file1_cleaned_df = clean_data(insurance_company_file1_df)
insurance_company_file2_cleaned_df = clean_data(insurance_company_file2_df)
insurance_company_file3_cleaned_df = clean_data(insurance_company_file3_df)

insurance_company_combined_df = pd.concat([insurance_company_file1_cleaned_df, insurance_company_file2_cleaned_df, insurance_company_file3_cleaned_df], ignore_index=1)
print(insurance_company_combined_df)
# Out:
#       customer       state gender             education  \
# 0      RB50392  Washington    NaN                Master
# 1      QZ44356     Arizona      F              Bachelor
# 2      AI49188      Nevada      F              Bachelor
# 3      WW63253  California      M              Bachelor
# 4      GA49547  Washington      M  High School or Below
# ...        ...         ...    ...                   ...
# 12069  LA72316  California      M              Bachelor
# 12070  PK87824  California      F               College
# 12071  TD14365  California      M              Bachelor
# 12072  UP19263  California      M               College
# 12073  Y167826  California      M               College
#
#       customer_lifetime_value   income  monthly_premium_auto  \
# 0                        <NA>      0.0                1000.0
# 1                   697953.59      0.0                  94.0
# 2                  1288743.17  48767.0                 108.0
# ...

# %% [markdown]
# # Challenge 2: Structuring Data

# %% [markdown]
# In this challenge, we will continue to work with customer data from an insurance company, but we will use a dataset with more columns, called marketing_customer_analysis.csv, which can be found at the following link:
#
# https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis_clean.csv
#
# This dataset contains information such as customer demographics, policy details, vehicle information, and the customer's response to the last marketing campaign. Our goal is to explore and analyze this data by performing data cleaning, formatting, and structuring.

# %%
import pandas as pd
url = "https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis_clean.csv"
marketing_customer_analysis_df = pd.read_csv(url)

display(marketing_customer_analysis_df)
# Out:
#        unnamed:_0 customer       state  customer_lifetime_value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877  California              6857.519928       No
#
#        coverage education effective_to_date employmentstatus gender  ...  \
# ...

# %%
import pandas as pd

def clean_data(df):
    # Step 1: Standardize Column Names
    df.columns = df.columns.str.lower().str.replace(' ', '_')
    
    # Step 2: Convert Data Types
    df['effective_to_date'] = pd.to_datetime(df['effective_to_date'])
    
    # Check if customer_lifetime_value column contains string values
    if df['customer_lifetime_value'].dtype == 'object':
        df['customer_lifetime_value'] = df['customer_lifetime_value'].str.rstrip('%').astype('float')
    
    # Format total_claim_amount column
    df['total_claim_amount'] = df['total_claim_amount'].round(2)
    
    # Step 3: Handle Missing Values
    df.dropna(inplace=True)
    
    # Step 4: Drop Duplicate Rows
    df.drop_duplicates(inplace=True)
    
    # Step 5: Structuring Data
    df['month'] = df['effective_to_date'].dt.month
    
    return df


# Clean the data
cleaned_data = clean_data(marketing_data)

print("DataFrame after cleaning, formatting, and structuring:")
display(cleaned_data.head())
# Out:
# DataFrame after cleaning, formatting, and structuring:
#    unnamed:_0 customer       state  customer_lifetime_value response  \
# 0           0  DK49336     Arizona              4809.216960       No
# 1           1  KX64629  California              2228.525238       No
# 2           2  LZ68649  Washington             14947.917300       No
# 3           3  XL78013      Oregon             22332.439460      Yes
# 4           4  QA50777      Oregon              9025.067525       No
#
#    coverage education effective_to_date employmentstatus gender  ...  \
# 0     Basic   College        2011-02-18         Employed      M  ...
# 1     Basic   College        2011-01-18       Unemployed      F  ...
# 2     Basic  Bachelor        2011-02-10         Employed      M  ...
# 3  Extended   College        2011-01-11         Employed      M  ...
# 4   Premium  Bachelor        2011-01-17    Medical Leave      F  ...
#
#    number_of_policies     policy_type        policy  renew_offer_type  \
# ...

# %%
# Task 1: Calculate total revenue for each sales channel using a pivot table
total_revenue = marketing_data.pivot_table(values='total_claim_amount', index='sales_channel', aggfunc='sum').round(2)

print("\nTask 1: Total Revenue for Each Sales Channel (Pivot Table):")
display(total_revenue)

# Task 2: Create a pivot table showing the average customer lifetime value per gender and education level
avg_clv_pivot = marketing_data.pivot_table(values='customer_lifetime_value', index=['gender', 'education'], aggfunc='mean')

print("\nTask 2: Average Customer Lifetime Value per Gender and Education Level (Pivot Table):")
display(avg_clv_pivot)

# %% [markdown]
# 1. You work at the marketing department and you want to know which sales channel brought the most sales in terms of total revenue. Using pivot, create a summary table showing the total revenue for each sales channel (branch, call center, web, and mail).
# Round the total revenue to 2 decimal points.  Analyze the resulting table to draw insights.

# %% [markdown]
# 2. Create a pivot table that shows the average customer lifetime value per gender and education level. Analyze the resulting table to draw insights.

# %% [markdown]
# ## Bonus
#
# You work at the customer service department and you want to know which months had the highest number of complaints by policy type category. Create a summary table showing the number of complaints by policy type and month.
# Show it in a long format table.

# %% [markdown]
# *In data analysis, a long format table is a way of structuring data in which each observation or measurement is stored in a separate row of the table. The key characteristic of a long format table is that each column represents a single variable, and each row represents a single observation of that variable.*
#
# *More information about long and wide format tables here: https://www.statology.org/long-vs-wide-data/*

# %%
# Your code goes here

# %%
import pandas as pd

# Step 1: Read the existing clean file from the previous lab
existing_clean_file = "path_to_existing_clean_file.csv"  # Replace "path_to_existing_clean_file.csv" with the actual file path
existing_data = pd.read_csv(existing_clean_file)

# Step 2: Read the two new data files
new_file2 = "https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file2.csv"
new_file3 = "https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file3.csv"
new_data2 = pd.read_csv(new_file2)
new_data3 = pd.read_csv(new_file3)

# Step 3: Apply cleaning and formatting functions to each of the new datasets
# Assuming you have functions defined for cleaning and formatting, apply them to new_data2 and new_data3

# Step 4: Concatenate all three datasets
combined_data = pd.concat([existing_data, new_data2, new_data3], ignore_index=True)

# Step 5: Perform any additional cleaning or formatting steps necessary for the combined dataset
# This could include handling missing values, correcting data types, etc.

# Display the combined dataset
print(combined_data)

# %% [markdown]
# ### Data Description
#
# - Customer - Customer ID
#
# - ST - State where customers live
#
# - Gender - Gender of the customer
#
# - Education - Background education of customers
#
# - Customer Lifetime Value - Customer lifetime value(CLV) is the total revenue the client will derive from their entire relationship with a customer. In other words, is the predicted or calculated value of a customer over their entire duration as a policyholder with the insurance company. It is an estimation of the net profit that the insurance company expects to generate from a customer throughout their relationship with the company. Customer Lifetime Value takes into account factors such as the duration of the customer's policy, premium payments, claim history, renewal likelihood, and potential additional services or products the customer may purchase. It helps insurers assess the long-term profitability and value associated with retaining a particular customer.
#
# - Income - Customers income
#
# - Monthly Premium Auto - Amount of money the customer pays on a monthly basis as a premium for their auto insurance coverage. It represents the recurring cost that the insured person must pay to maintain their insurance policy and receive coverage for potential damages, accidents, or other covered events related to their vehicle.
#
# - Number of Open Complaints - Number of complaints the customer opened
#
# - Policy Type - There are three type of policies in car insurance (Corporate Auto, Personal Auto, and Special Auto)
#
# - Vehicle Class - Type of vehicle classes that customers have Two-Door Car, Four-Door Car SUV, Luxury SUV, Sports Car, and Luxury Car
#
# - Total Claim Amount - the sum of all claims made by the customer. It represents the total monetary value of all approved claims for incidents such as accidents, theft, vandalism, or other covered events.
